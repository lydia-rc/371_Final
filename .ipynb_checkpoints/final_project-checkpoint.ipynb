# %%
# importing necessary packages
import numpy as np
import pandas as pd

# %%
# reading in the data set
df = pd.read_csv('mig174.csv', dtype='string', keep_default_na=False)

# %%
# selecting features
new_df = df[['sex','age','statebrn','marstat','edyrs','occ','@by','usdoc1','usstate1','usocc1','uswage1','usby1',
             'ustrips','usexp','crsst1','crspl1','crshow1','crscoy1','crscst1','crsdep1']]

# %%
# removing all 1111s (Border was crossed by airplane), 8888s (N/A), or 9999s (Unknown)

feature_names = ['sex','age','statebrn','marstat','edyrs','occ','@by','usdoc1','usstate1','usocc1','uswage1','usby1','ustrips',
   'usexp','crsst1','crspl1','crshow1','crscoy1','crscst1','crsdep1']

for i in range(len(feature_names)):
    new_df = new_df.drop(new_df[(new_df[feature_names[i]]=='1111')].index)
    new_df = new_df.drop(new_df[(new_df[feature_names[i]]=='8888')].index)
    new_df = new_df.drop(new_df[(new_df[feature_names[i]]=='9999')].index)

# %%
# converting strings to floats to train models
new_df = new_df.astype(float)

# %%
# converting targets to binary values
new_df.loc[new_df['crsdep1'] > 0, 'crsdep1'] = 1
new_df
# Out:
#       sex   age  statebrn  marstat  edyrs    occ  @by  usdoc1  usstate1  \
# 6     1.0  37.0      11.0      1.0    6.0  410.0  5.0     8.0     105.0
# 34    1.0  36.0      11.0      2.0    2.0  529.0  5.0     8.0     105.0
# 48    1.0  35.0      11.0      2.0    6.0  559.0  5.0     8.0     105.0
# 77    1.0  33.0      11.0      2.0    0.0  810.0  1.0     8.0     129.0
# 83    1.0  20.0      11.0      1.0    9.0  810.0  1.0     8.0     129.0
# ...   ...   ...       ...      ...    ...    ...  ...     ...       ...
# 9034  1.0  66.0      20.0      2.0    3.0  410.0  3.0     8.0     105.0
# 9043  1.0  50.0      20.0      2.0    3.0  546.0  2.0     8.0     105.0
# 9047  1.0  78.0      20.0      2.0    4.0  410.0  3.0     8.0     105.0
# 9048  1.0  34.0      20.0      2.0    6.0  546.0  3.0     8.0     105.0
# 9049  1.0  49.0      20.0      2.0    6.0  410.0  3.0     8.0     105.0
#
#       usocc1  uswage1  usby1  ustrips  usexp  crsst1  crspl1  crshow1  \
# 6      410.0     2.25    1.0      2.0   84.0     2.0     4.0      1.0
# 34     410.0     3.35    1.0      3.0   32.0     2.0     4.0      1.0
# 48     810.0     3.00    1.0      1.0   12.0     2.0     4.0      1.0
# 77     810.0     3.10    1.0      2.0  114.0     2.0     2.0      1.0
# 83     549.0     4.55    1.0      1.0   42.0     2.0     4.0      1.0
# ...      ...      ...    ...      ...    ...     ...     ...      ...
# 9034   812.0    40.00    2.0      1.0  120.0     2.0     4.0      1.0
# 9043   812.0    50.00    2.0      2.0   72.0     2.0     4.0      1.0
# 9047   410.0     3.00    1.0      1.0   60.0     2.0     4.0      3.0
# 9048   812.0    70.00    2.0      1.0   24.0     2.0     4.0      3.0
# 9049   812.0    26.00    2.0      2.0   96.0     2.0     4.0      3.0
#
#       crscoy1  crscst1  crsdep1
# 6         1.0    150.0      0.0
# 34        1.0     60.0      1.0
# 48        1.0    100.0      0.0
# 77        1.0    300.0      0.0
# 83        1.0    350.0      0.0
# ...       ...      ...      ...
# 9034      1.0    300.0      0.0
# 9043      1.0    300.0      0.0
# 9047      1.0   5000.0      0.0
# 9048      1.0  15000.0      0.0
# 9049      1.0    300.0      0.0
#
# [1304 rows x 20 columns]

# %%
features = new_df[['sex','age','statebrn','marstat','edyrs','occ','@by','usdoc1','usstate1','usocc1','uswage1','usby1',
             'ustrips','usexp','crsst1','crspl1','crshow1','crscoy1','crscst1']]

target = new_df['crsdep1']

# %%
"""
SVM testing
"""
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

X = np.array(features)
y = np.array(target)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

make_pipe = make_pipeline(StandardScaler(), SVC())
  
# defining parameter range
param_grid = {'svc__C': [0.001, 0.1, 1, 10, 100], 
              'svc__degree': [1, 2, 3, 4, 5],
              'svc__gamma': [1, 0.1, 0.01, 0.001, 0.0001],
              'svc__kernel': ['rbf', 'linear', 'poly']} 
  
#grid = GridSearchCV(SVC(), param_grid, refit = True, verbose = 3)

grid = GridSearchCV(make_pipe, param_grid, refit = True, verbose = 3)
  
# fitting the model for grid search
grid.fit(X_train, y_train)

print(grid.best_params_)
print(grid.best_estimator_)
# Out:
# Fitting 5 folds for each of 375 candidates, totalling 1875 fits
# [CV 1/5] END svc__C=0.001, svc__degree=1, svc__gamma=1, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=1, svc__gamma=1, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=1, svc__gamma=1, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=1, svc__gamma=1, svc__kernel=rbf;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=1, svc__gamma=1, svc__kernel=rbf;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=1, svc__gamma=1, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=1, svc__gamma=1, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=1, svc__gamma=1, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=1, svc__gamma=1, svc__kernel=linear;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=1, svc__gamma=1, svc__kernel=linear;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=1, svc__gamma=1, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=1, svc__gamma=1, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=1, svc__gamma=1, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=1, svc__gamma=1, svc__kernel=poly;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=1, svc__gamma=1, svc__kernel=poly;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.1, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.1, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.1, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.1, svc__kernel=rbf;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.1, svc__kernel=rbf;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.1, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.1, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.1, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.1, svc__kernel=linear;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.1, svc__kernel=linear;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.1, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.1, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.1, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.1, svc__kernel=poly;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.1, svc__kernel=poly;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.01, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.01, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.01, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.01, svc__kernel=rbf;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.01, svc__kernel=rbf;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.01, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.01, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.01, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.01, svc__kernel=linear;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.01, svc__kernel=linear;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.01, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.01, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.01, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.01, svc__kernel=poly;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.01, svc__kernel=poly;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.001, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.001, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.001, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.001, svc__kernel=rbf;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.001, svc__kernel=rbf;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.001, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.001, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.001, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.001, svc__kernel=linear;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.001, svc__kernel=linear;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.001, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.001, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.001, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.001, svc__kernel=poly;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.001, svc__kernel=poly;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.0001, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.0001, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.0001, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.0001, svc__kernel=rbf;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.0001, svc__kernel=rbf;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.0001, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.0001, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.0001, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.0001, svc__kernel=linear;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.0001, svc__kernel=linear;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.0001, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.0001, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.0001, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.0001, svc__kernel=poly;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=1, svc__gamma=0.0001, svc__kernel=poly;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=2, svc__gamma=1, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=2, svc__gamma=1, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=2, svc__gamma=1, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=2, svc__gamma=1, svc__kernel=rbf;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=2, svc__gamma=1, svc__kernel=rbf;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=2, svc__gamma=1, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=2, svc__gamma=1, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=2, svc__gamma=1, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=2, svc__gamma=1, svc__kernel=linear;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=2, svc__gamma=1, svc__kernel=linear;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=2, svc__gamma=1, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=2, svc__gamma=1, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=2, svc__gamma=1, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=2, svc__gamma=1, svc__kernel=poly;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=2, svc__gamma=1, svc__kernel=poly;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.1, svc__kernel=rbf;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.1, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.1, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.1, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.1, svc__kernel=linear;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.1, svc__kernel=linear;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.1, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.1, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.1, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.1, svc__kernel=poly;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.1, svc__kernel=poly;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.01, svc__kernel=rbf;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.01, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.01, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.01, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.01, svc__kernel=linear;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.01, svc__kernel=linear;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.01, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.01, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.01, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.01, svc__kernel=poly;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.01, svc__kernel=poly;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.001, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.001, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.001, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.001, svc__kernel=rbf;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.001, svc__kernel=rbf;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.001, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.001, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.001, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.001, svc__kernel=linear;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.001, svc__kernel=linear;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.001, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.001, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.001, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.001, svc__kernel=poly;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.001, svc__kernel=poly;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.0001, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.0001, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.0001, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.0001, svc__kernel=rbf;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.0001, svc__kernel=rbf;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.0001, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.0001, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.0001, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.0001, svc__kernel=linear;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.0001, svc__kernel=linear;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.0001, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.0001, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.0001, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.0001, svc__kernel=poly;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=2, svc__gamma=0.0001, svc__kernel=poly;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=3, svc__gamma=1, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=3, svc__gamma=1, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=3, svc__gamma=1, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=3, svc__gamma=1, svc__kernel=rbf;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=3, svc__gamma=1, svc__kernel=rbf;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=3, svc__gamma=1, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=3, svc__gamma=1, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=3, svc__gamma=1, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=3, svc__gamma=1, svc__kernel=linear;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=3, svc__gamma=1, svc__kernel=linear;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=3, svc__gamma=1, svc__kernel=poly;, score=0.781 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=3, svc__gamma=1, svc__kernel=poly;, score=0.704 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=3, svc__gamma=1, svc__kernel=poly;, score=0.730 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=3, svc__gamma=1, svc__kernel=poly;, score=0.723 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=3, svc__gamma=1, svc__kernel=poly;, score=0.749 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.1, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.1, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.1, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.1, svc__kernel=rbf;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.1, svc__kernel=rbf;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.1, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.1, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.1, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.1, svc__kernel=linear;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.1, svc__kernel=linear;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.1, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.1, svc__kernel=poly;, score=0.765 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.1, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.1, svc__kernel=poly;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.1, svc__kernel=poly;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.01, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.01, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.01, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.01, svc__kernel=rbf;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.01, svc__kernel=rbf;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.01, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.01, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.01, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.01, svc__kernel=linear;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.01, svc__kernel=linear;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.01, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.01, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.01, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.01, svc__kernel=poly;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.01, svc__kernel=poly;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.001, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.001, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.001, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.001, svc__kernel=rbf;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.001, svc__kernel=rbf;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.001, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.001, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.001, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.001, svc__kernel=linear;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.001, svc__kernel=linear;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.001, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.001, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.001, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.001, svc__kernel=poly;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.001, svc__kernel=poly;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.0001, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.0001, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.0001, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.0001, svc__kernel=rbf;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.0001, svc__kernel=rbf;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.0001, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.0001, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.0001, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.0001, svc__kernel=linear;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.0001, svc__kernel=linear;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.0001, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.0001, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.0001, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.0001, svc__kernel=poly;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=3, svc__gamma=0.0001, svc__kernel=poly;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=4, svc__gamma=1, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=4, svc__gamma=1, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=4, svc__gamma=1, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=4, svc__gamma=1, svc__kernel=rbf;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=4, svc__gamma=1, svc__kernel=rbf;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=4, svc__gamma=1, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=4, svc__gamma=1, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=4, svc__gamma=1, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=4, svc__gamma=1, svc__kernel=linear;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=4, svc__gamma=1, svc__kernel=linear;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=4, svc__gamma=1, svc__kernel=poly;, score=0.663 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=4, svc__gamma=1, svc__kernel=poly;, score=0.582 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=4, svc__gamma=1, svc__kernel=poly;, score=0.663 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=4, svc__gamma=1, svc__kernel=poly;, score=0.656 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=4, svc__gamma=1, svc__kernel=poly;, score=0.703 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.1, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.1, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.1, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.1, svc__kernel=linear;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.1, svc__kernel=linear;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.1, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.1, svc__kernel=poly;, score=0.755 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.1, svc__kernel=poly;, score=0.765 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.1, svc__kernel=poly;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.1, svc__kernel=poly;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.01, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.01, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.01, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.01, svc__kernel=linear;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.01, svc__kernel=linear;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.01, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.01, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.01, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.01, svc__kernel=poly;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.01, svc__kernel=poly;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.001, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.001, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.001, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.001, svc__kernel=rbf;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.001, svc__kernel=rbf;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.001, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.001, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.001, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.001, svc__kernel=linear;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.001, svc__kernel=linear;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.001, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.001, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.001, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.001, svc__kernel=poly;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.001, svc__kernel=poly;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.0001, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.0001, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.0001, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.0001, svc__kernel=rbf;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.0001, svc__kernel=rbf;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.0001, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.0001, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.0001, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.0001, svc__kernel=linear;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.0001, svc__kernel=linear;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.0001, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.0001, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.0001, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.0001, svc__kernel=poly;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=4, svc__gamma=0.0001, svc__kernel=poly;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=5, svc__gamma=1, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=5, svc__gamma=1, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=5, svc__gamma=1, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=5, svc__gamma=1, svc__kernel=rbf;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=5, svc__gamma=1, svc__kernel=rbf;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=5, svc__gamma=1, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=5, svc__gamma=1, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=5, svc__gamma=1, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=5, svc__gamma=1, svc__kernel=linear;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=5, svc__gamma=1, svc__kernel=linear;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=5, svc__gamma=1, svc__kernel=poly;, score=0.658 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=5, svc__gamma=1, svc__kernel=poly;, score=0.679 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=5, svc__gamma=1, svc__kernel=poly;, score=0.638 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=5, svc__gamma=1, svc__kernel=poly;, score=0.677 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=5, svc__gamma=1, svc__kernel=poly;, score=0.713 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.1, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.1, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.1, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.1, svc__kernel=rbf;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.1, svc__kernel=rbf;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.1, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.1, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.1, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.1, svc__kernel=linear;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.1, svc__kernel=linear;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.1, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.1, svc__kernel=poly;, score=0.765 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.1, svc__kernel=poly;, score=0.755 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.1, svc__kernel=poly;, score=0.759 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.1, svc__kernel=poly;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.01, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.01, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.01, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.01, svc__kernel=rbf;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.01, svc__kernel=rbf;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.01, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.01, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.01, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.01, svc__kernel=linear;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.01, svc__kernel=linear;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.01, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.01, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.01, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.01, svc__kernel=poly;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.01, svc__kernel=poly;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.001, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.001, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.001, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.001, svc__kernel=rbf;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.001, svc__kernel=rbf;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.001, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.001, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.001, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.001, svc__kernel=linear;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.001, svc__kernel=linear;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.001, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.001, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.001, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.001, svc__kernel=poly;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.001, svc__kernel=poly;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.0001, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.0001, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.0001, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.0001, svc__kernel=rbf;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.0001, svc__kernel=rbf;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.0001, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.0001, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.0001, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.0001, svc__kernel=linear;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.0001, svc__kernel=linear;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.0001, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.0001, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.0001, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.0001, svc__kernel=poly;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.001, svc__degree=5, svc__gamma=0.0001, svc__kernel=poly;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.1, svc__degree=1, svc__gamma=1, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.1, svc__degree=1, svc__gamma=1, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.1, svc__degree=1, svc__gamma=1, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.1, svc__degree=1, svc__gamma=1, svc__kernel=rbf;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.1, svc__degree=1, svc__gamma=1, svc__kernel=rbf;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.1, svc__degree=1, svc__gamma=1, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.1, svc__degree=1, svc__gamma=1, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.1, svc__degree=1, svc__gamma=1, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.1, svc__degree=1, svc__gamma=1, svc__kernel=linear;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.1, svc__degree=1, svc__gamma=1, svc__kernel=linear;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.1, svc__degree=1, svc__gamma=1, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.1, svc__degree=1, svc__gamma=1, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.1, svc__degree=1, svc__gamma=1, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.1, svc__degree=1, svc__gamma=1, svc__kernel=poly;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.1, svc__degree=1, svc__gamma=1, svc__kernel=poly;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.1, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.1, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.1, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.1, svc__kernel=rbf;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.1, svc__kernel=rbf;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.1, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.1, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.1, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.1, svc__kernel=linear;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.1, svc__kernel=linear;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.1, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.1, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.1, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.1, svc__kernel=poly;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.1, svc__kernel=poly;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.01, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.01, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.01, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.01, svc__kernel=rbf;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.01, svc__kernel=rbf;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.01, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.01, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.01, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.01, svc__kernel=linear;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.01, svc__kernel=linear;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.01, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.01, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.01, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.01, svc__kernel=poly;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.01, svc__kernel=poly;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.001, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.001, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.001, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.001, svc__kernel=rbf;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.001, svc__kernel=rbf;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.001, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.001, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.001, svc__kernel=linear;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.001, svc__kernel=linear;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.001, svc__kernel=linear;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.001, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.001, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.001, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.001, svc__kernel=poly;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.001, svc__kernel=poly;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.0001, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.0001, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.0001, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.0001, svc__kernel=rbf;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=0.1, svc__degree=1, svc__gamma=0.0001, svc__kernel=rbf;, score=0.769 total time=   0.0s
# ...
# [CV 4/5] END svc__C=100, svc__degree=4, svc__gamma=1, svc__kernel=rbf;, score=0.769 total time=   0.0s
# [CV 5/5] END svc__C=100, svc__degree=4, svc__gamma=1, svc__kernel=rbf;, score=0.759 total time=   0.0s
# [CV 1/5] END svc__C=100, svc__degree=4, svc__gamma=1, svc__kernel=linear;, score=0.770 total time= 1.4min
# [CV 2/5] END svc__C=100, svc__degree=4, svc__gamma=1, svc__kernel=linear;, score=0.770 total time= 1.0min
# [CV 3/5] END svc__C=100, svc__degree=4, svc__gamma=1, svc__kernel=linear;, score=0.770 total time=  58.9s
# [CV 4/5] END svc__C=100, svc__degree=4, svc__gamma=1, svc__kernel=linear;, score=0.774 total time= 1.1min
# [CV 5/5] END svc__C=100, svc__degree=4, svc__gamma=1, svc__kernel=linear;, score=0.769 total time=  40.5s
# [CV 1/5] END svc__C=100, svc__degree=4, svc__gamma=1, svc__kernel=poly;, score=0.648 total time=   0.0s
# [CV 2/5] END svc__C=100, svc__degree=4, svc__gamma=1, svc__kernel=poly;, score=0.638 total time=   0.0s
# [CV 3/5] END svc__C=100, svc__degree=4, svc__gamma=1, svc__kernel=poly;, score=0.643 total time=   0.0s
# [CV 4/5] END svc__C=100, svc__degree=4, svc__gamma=1, svc__kernel=poly;, score=0.636 total time=   0.0s
# [CV 5/5] END svc__C=100, svc__degree=4, svc__gamma=1, svc__kernel=poly;, score=0.651 total time=   0.0s
# [CV 1/5] END svc__C=100, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf;, score=0.663 total time=   0.0s
# [CV 2/5] END svc__C=100, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf;, score=0.648 total time=   0.0s
# [CV 3/5] END svc__C=100, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf;, score=0.648 total time=   0.0s
# [CV 4/5] END svc__C=100, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf;, score=0.656 total time=   0.0s
# [CV 5/5] END svc__C=100, svc__degree=4, svc__gamma=0.1, svc__kernel=rbf;, score=0.687 total time=   0.0s
# [CV 1/5] END svc__C=100, svc__degree=4, svc__gamma=0.1, svc__kernel=linear;, score=0.770 total time= 1.4min
# [CV 2/5] END svc__C=100, svc__degree=4, svc__gamma=0.1, svc__kernel=linear;, score=0.770 total time= 1.1min
# [CV 3/5] END svc__C=100, svc__degree=4, svc__gamma=0.1, svc__kernel=linear;, score=0.770 total time=  58.8s
# [CV 4/5] END svc__C=100, svc__degree=4, svc__gamma=0.1, svc__kernel=linear;, score=0.774 total time= 1.1min
# [CV 5/5] END svc__C=100, svc__degree=4, svc__gamma=0.1, svc__kernel=linear;, score=0.769 total time=  40.5s
# [CV 1/5] END svc__C=100, svc__degree=4, svc__gamma=0.1, svc__kernel=poly;, score=0.643 total time=   0.0s
# [CV 2/5] END svc__C=100, svc__degree=4, svc__gamma=0.1, svc__kernel=poly;, score=0.592 total time=   0.0s
# [CV 3/5] END svc__C=100, svc__degree=4, svc__gamma=0.1, svc__kernel=poly;, score=0.658 total time=   0.0s
# [CV 4/5] END svc__C=100, svc__degree=4, svc__gamma=0.1, svc__kernel=poly;, score=0.651 total time=   0.0s
# [CV 5/5] END svc__C=100, svc__degree=4, svc__gamma=0.1, svc__kernel=poly;, score=0.656 total time=   0.0s
# [CV 1/5] END svc__C=100, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf;, score=0.765 total time=   0.0s
# [CV 2/5] END svc__C=100, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf;, score=0.745 total time=   0.1s
# [CV 3/5] END svc__C=100, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf;, score=0.755 total time=   0.0s
# [CV 4/5] END svc__C=100, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf;, score=0.744 total time=   0.0s
# [CV 5/5] END svc__C=100, svc__degree=4, svc__gamma=0.01, svc__kernel=rbf;, score=0.738 total time=   0.1s
# [CV 1/5] END svc__C=100, svc__degree=4, svc__gamma=0.01, svc__kernel=linear;, score=0.770 total time= 1.4min
# [CV 2/5] END svc__C=100, svc__degree=4, svc__gamma=0.01, svc__kernel=linear;, score=0.770 total time= 1.1min
# [CV 3/5] END svc__C=100, svc__degree=4, svc__gamma=0.01, svc__kernel=linear;, score=0.770 total time=  59.1s
# [CV 4/5] END svc__C=100, svc__degree=4, svc__gamma=0.01, svc__kernel=linear;, score=0.774 total time= 1.1min
# [CV 5/5] END svc__C=100, svc__degree=4, svc__gamma=0.01, svc__kernel=linear;, score=0.769 total time=  39.0s
# [CV 1/5] END svc__C=100, svc__degree=4, svc__gamma=0.01, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=100, svc__degree=4, svc__gamma=0.01, svc__kernel=poly;, score=0.755 total time=   0.0s
# [CV 3/5] END svc__C=100, svc__degree=4, svc__gamma=0.01, svc__kernel=poly;, score=0.755 total time=   0.0s
# [CV 4/5] END svc__C=100, svc__degree=4, svc__gamma=0.01, svc__kernel=poly;, score=0.769 total time=   0.0s
# [CV 5/5] END svc__C=100, svc__degree=4, svc__gamma=0.01, svc__kernel=poly;, score=0.764 total time=   0.0s
# [CV 1/5] END svc__C=100, svc__degree=4, svc__gamma=0.001, svc__kernel=rbf;, score=0.770 total time=   0.1s
# [CV 2/5] END svc__C=100, svc__degree=4, svc__gamma=0.001, svc__kernel=rbf;, score=0.760 total time=   0.1s
# [CV 3/5] END svc__C=100, svc__degree=4, svc__gamma=0.001, svc__kernel=rbf;, score=0.770 total time=   0.1s
# [CV 4/5] END svc__C=100, svc__degree=4, svc__gamma=0.001, svc__kernel=rbf;, score=0.774 total time=   0.1s
# [CV 5/5] END svc__C=100, svc__degree=4, svc__gamma=0.001, svc__kernel=rbf;, score=0.769 total time=   0.1s
# [CV 1/5] END svc__C=100, svc__degree=4, svc__gamma=0.001, svc__kernel=linear;, score=0.770 total time= 1.4min
# [CV 2/5] END svc__C=100, svc__degree=4, svc__gamma=0.001, svc__kernel=linear;, score=0.770 total time= 1.0min
# [CV 3/5] END svc__C=100, svc__degree=4, svc__gamma=0.001, svc__kernel=linear;, score=0.770 total time=  57.2s
# [CV 4/5] END svc__C=100, svc__degree=4, svc__gamma=0.001, svc__kernel=linear;, score=0.774 total time= 1.0min
# [CV 5/5] END svc__C=100, svc__degree=4, svc__gamma=0.001, svc__kernel=linear;, score=0.769 total time=  39.3s
# [CV 1/5] END svc__C=100, svc__degree=4, svc__gamma=0.001, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=100, svc__degree=4, svc__gamma=0.001, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=100, svc__degree=4, svc__gamma=0.001, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=100, svc__degree=4, svc__gamma=0.001, svc__kernel=poly;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=100, svc__degree=4, svc__gamma=0.001, svc__kernel=poly;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=100, svc__degree=4, svc__gamma=0.0001, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=100, svc__degree=4, svc__gamma=0.0001, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=100, svc__degree=4, svc__gamma=0.0001, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=100, svc__degree=4, svc__gamma=0.0001, svc__kernel=rbf;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=100, svc__degree=4, svc__gamma=0.0001, svc__kernel=rbf;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=100, svc__degree=4, svc__gamma=0.0001, svc__kernel=linear;, score=0.770 total time= 1.4min
# [CV 2/5] END svc__C=100, svc__degree=4, svc__gamma=0.0001, svc__kernel=linear;, score=0.770 total time= 1.0min
# [CV 3/5] END svc__C=100, svc__degree=4, svc__gamma=0.0001, svc__kernel=linear;, score=0.770 total time=  56.9s
# [CV 4/5] END svc__C=100, svc__degree=4, svc__gamma=0.0001, svc__kernel=linear;, score=0.774 total time= 1.0min
# [CV 5/5] END svc__C=100, svc__degree=4, svc__gamma=0.0001, svc__kernel=linear;, score=0.769 total time=  38.6s
# [CV 1/5] END svc__C=100, svc__degree=4, svc__gamma=0.0001, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=100, svc__degree=4, svc__gamma=0.0001, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=100, svc__degree=4, svc__gamma=0.0001, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=100, svc__degree=4, svc__gamma=0.0001, svc__kernel=poly;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=100, svc__degree=4, svc__gamma=0.0001, svc__kernel=poly;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=100, svc__degree=5, svc__gamma=1, svc__kernel=rbf;, score=0.776 total time=   0.0s
# [CV 2/5] END svc__C=100, svc__degree=5, svc__gamma=1, svc__kernel=rbf;, score=0.755 total time=   0.0s
# [CV 3/5] END svc__C=100, svc__degree=5, svc__gamma=1, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=100, svc__degree=5, svc__gamma=1, svc__kernel=rbf;, score=0.769 total time=   0.0s
# [CV 5/5] END svc__C=100, svc__degree=5, svc__gamma=1, svc__kernel=rbf;, score=0.759 total time=   0.0s
# [CV 1/5] END svc__C=100, svc__degree=5, svc__gamma=1, svc__kernel=linear;, score=0.770 total time= 1.3min
# [CV 2/5] END svc__C=100, svc__degree=5, svc__gamma=1, svc__kernel=linear;, score=0.770 total time= 1.0min
# [CV 3/5] END svc__C=100, svc__degree=5, svc__gamma=1, svc__kernel=linear;, score=0.770 total time=  56.2s
# [CV 4/5] END svc__C=100, svc__degree=5, svc__gamma=1, svc__kernel=linear;, score=0.774 total time= 1.0min
# [CV 5/5] END svc__C=100, svc__degree=5, svc__gamma=1, svc__kernel=linear;, score=0.769 total time=  38.6s
# [CV 1/5] END svc__C=100, svc__degree=5, svc__gamma=1, svc__kernel=poly;, score=0.663 total time=   0.0s
# [CV 2/5] END svc__C=100, svc__degree=5, svc__gamma=1, svc__kernel=poly;, score=0.668 total time=   0.0s
# [CV 3/5] END svc__C=100, svc__degree=5, svc__gamma=1, svc__kernel=poly;, score=0.617 total time=   0.0s
# [CV 4/5] END svc__C=100, svc__degree=5, svc__gamma=1, svc__kernel=poly;, score=0.667 total time=   0.0s
# [CV 5/5] END svc__C=100, svc__degree=5, svc__gamma=1, svc__kernel=poly;, score=0.667 total time=   0.0s
# [CV 1/5] END svc__C=100, svc__degree=5, svc__gamma=0.1, svc__kernel=rbf;, score=0.663 total time=   0.0s
# [CV 2/5] END svc__C=100, svc__degree=5, svc__gamma=0.1, svc__kernel=rbf;, score=0.648 total time=   0.0s
# [CV 3/5] END svc__C=100, svc__degree=5, svc__gamma=0.1, svc__kernel=rbf;, score=0.648 total time=   0.0s
# [CV 4/5] END svc__C=100, svc__degree=5, svc__gamma=0.1, svc__kernel=rbf;, score=0.656 total time=   0.0s
# [CV 5/5] END svc__C=100, svc__degree=5, svc__gamma=0.1, svc__kernel=rbf;, score=0.687 total time=   0.0s
# [CV 1/5] END svc__C=100, svc__degree=5, svc__gamma=0.1, svc__kernel=linear;, score=0.770 total time= 1.3min
# [CV 2/5] END svc__C=100, svc__degree=5, svc__gamma=0.1, svc__kernel=linear;, score=0.770 total time= 1.0min
# [CV 3/5] END svc__C=100, svc__degree=5, svc__gamma=0.1, svc__kernel=linear;, score=0.770 total time=  55.9s
# [CV 4/5] END svc__C=100, svc__degree=5, svc__gamma=0.1, svc__kernel=linear;, score=0.774 total time= 1.0min
# [CV 5/5] END svc__C=100, svc__degree=5, svc__gamma=0.1, svc__kernel=linear;, score=0.769 total time=  38.9s
# [CV 1/5] END svc__C=100, svc__degree=5, svc__gamma=0.1, svc__kernel=poly;, score=0.658 total time=   0.0s
# [CV 2/5] END svc__C=100, svc__degree=5, svc__gamma=0.1, svc__kernel=poly;, score=0.679 total time=   0.0s
# [CV 3/5] END svc__C=100, svc__degree=5, svc__gamma=0.1, svc__kernel=poly;, score=0.638 total time=   0.0s
# [CV 4/5] END svc__C=100, svc__degree=5, svc__gamma=0.1, svc__kernel=poly;, score=0.677 total time=   0.0s
# [CV 5/5] END svc__C=100, svc__degree=5, svc__gamma=0.1, svc__kernel=poly;, score=0.713 total time=   0.0s
# [CV 1/5] END svc__C=100, svc__degree=5, svc__gamma=0.01, svc__kernel=rbf;, score=0.765 total time=   0.0s
# [CV 2/5] END svc__C=100, svc__degree=5, svc__gamma=0.01, svc__kernel=rbf;, score=0.745 total time=   0.1s
# [CV 3/5] END svc__C=100, svc__degree=5, svc__gamma=0.01, svc__kernel=rbf;, score=0.755 total time=   0.0s
# [CV 4/5] END svc__C=100, svc__degree=5, svc__gamma=0.01, svc__kernel=rbf;, score=0.744 total time=   0.0s
# [CV 5/5] END svc__C=100, svc__degree=5, svc__gamma=0.01, svc__kernel=rbf;, score=0.738 total time=   0.1s
# [CV 1/5] END svc__C=100, svc__degree=5, svc__gamma=0.01, svc__kernel=linear;, score=0.770 total time= 1.4min
# [CV 2/5] END svc__C=100, svc__degree=5, svc__gamma=0.01, svc__kernel=linear;, score=0.770 total time= 1.1min
# [CV 3/5] END svc__C=100, svc__degree=5, svc__gamma=0.01, svc__kernel=linear;, score=0.770 total time=  58.7s
# [CV 4/5] END svc__C=100, svc__degree=5, svc__gamma=0.01, svc__kernel=linear;, score=0.774 total time= 1.1min
# [CV 5/5] END svc__C=100, svc__degree=5, svc__gamma=0.01, svc__kernel=linear;, score=0.769 total time=  40.3s
# [CV 1/5] END svc__C=100, svc__degree=5, svc__gamma=0.01, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=100, svc__degree=5, svc__gamma=0.01, svc__kernel=poly;, score=0.765 total time=   0.0s
# [CV 3/5] END svc__C=100, svc__degree=5, svc__gamma=0.01, svc__kernel=poly;, score=0.755 total time=   0.0s
# [CV 4/5] END svc__C=100, svc__degree=5, svc__gamma=0.01, svc__kernel=poly;, score=0.759 total time=   0.0s
# [CV 5/5] END svc__C=100, svc__degree=5, svc__gamma=0.01, svc__kernel=poly;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=100, svc__degree=5, svc__gamma=0.001, svc__kernel=rbf;, score=0.770 total time=   0.1s
# [CV 2/5] END svc__C=100, svc__degree=5, svc__gamma=0.001, svc__kernel=rbf;, score=0.760 total time=   0.1s
# [CV 3/5] END svc__C=100, svc__degree=5, svc__gamma=0.001, svc__kernel=rbf;, score=0.770 total time=   0.1s
# [CV 4/5] END svc__C=100, svc__degree=5, svc__gamma=0.001, svc__kernel=rbf;, score=0.774 total time=   0.1s
# [CV 5/5] END svc__C=100, svc__degree=5, svc__gamma=0.001, svc__kernel=rbf;, score=0.769 total time=   0.1s
# [CV 1/5] END svc__C=100, svc__degree=5, svc__gamma=0.001, svc__kernel=linear;, score=0.770 total time= 1.4min
# [CV 2/5] END svc__C=100, svc__degree=5, svc__gamma=0.001, svc__kernel=linear;, score=0.770 total time= 1.1min
# [CV 3/5] END svc__C=100, svc__degree=5, svc__gamma=0.001, svc__kernel=linear;, score=0.770 total time=  58.9s
# [CV 4/5] END svc__C=100, svc__degree=5, svc__gamma=0.001, svc__kernel=linear;, score=0.774 total time= 1.1min
# [CV 5/5] END svc__C=100, svc__degree=5, svc__gamma=0.001, svc__kernel=linear;, score=0.769 total time=  40.4s
# [CV 1/5] END svc__C=100, svc__degree=5, svc__gamma=0.001, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=100, svc__degree=5, svc__gamma=0.001, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=100, svc__degree=5, svc__gamma=0.001, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=100, svc__degree=5, svc__gamma=0.001, svc__kernel=poly;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=100, svc__degree=5, svc__gamma=0.001, svc__kernel=poly;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=100, svc__degree=5, svc__gamma=0.0001, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=100, svc__degree=5, svc__gamma=0.0001, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=100, svc__degree=5, svc__gamma=0.0001, svc__kernel=rbf;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=100, svc__degree=5, svc__gamma=0.0001, svc__kernel=rbf;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=100, svc__degree=5, svc__gamma=0.0001, svc__kernel=rbf;, score=0.769 total time=   0.0s
# [CV 1/5] END svc__C=100, svc__degree=5, svc__gamma=0.0001, svc__kernel=linear;, score=0.770 total time= 1.4min
# [CV 2/5] END svc__C=100, svc__degree=5, svc__gamma=0.0001, svc__kernel=linear;, score=0.770 total time= 1.1min
# [CV 3/5] END svc__C=100, svc__degree=5, svc__gamma=0.0001, svc__kernel=linear;, score=0.770 total time=  58.8s
# [CV 4/5] END svc__C=100, svc__degree=5, svc__gamma=0.0001, svc__kernel=linear;, score=0.774 total time= 1.1min
# [CV 5/5] END svc__C=100, svc__degree=5, svc__gamma=0.0001, svc__kernel=linear;, score=0.769 total time=  40.3s
# [CV 1/5] END svc__C=100, svc__degree=5, svc__gamma=0.0001, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 2/5] END svc__C=100, svc__degree=5, svc__gamma=0.0001, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 3/5] END svc__C=100, svc__degree=5, svc__gamma=0.0001, svc__kernel=poly;, score=0.770 total time=   0.0s
# [CV 4/5] END svc__C=100, svc__degree=5, svc__gamma=0.0001, svc__kernel=poly;, score=0.774 total time=   0.0s
# [CV 5/5] END svc__C=100, svc__degree=5, svc__gamma=0.0001, svc__kernel=poly;, score=0.769 total time=   0.0s
# {'svc__C': 0.001, 'svc__degree': 1, 'svc__gamma': 1, 'svc__kernel': 'rbf'}
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('svc', SVC(C=0.001, degree=1, gamma=1))])

# %%
# SVM best parameters:
# {'svc__C': 0.001, 'svc__degree': 1, 'svc__gamma': 1, 'svc__kernel': 'rbf'}
# Pipeline(steps=[('standardscaler', StandardScaler()), ('svc', SVC(C=0.001, degree=1, gamma=1))])

# %%
"""
SVM
"""
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline

X = np.array(features)
y = np.array(target)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

svm = SVC()

svm.fit(X_train, y_train)

pipe = Pipeline(steps=[('scaler',StandardScaler()), ('svm', SVC(C=0.001, degree=1, gamma=1, kernel = 'rbf'))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.803680981595092

# %%
"""
Logistic Regression
"""

from sklearn.linear_model import LogisticRegression

X = np.array(features)
y = np.array(target)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

logreg = LogisticRegression().fit(X_train, y_train)
logreg.predict(X_test)
logreg.score(X_test, y_test)
# Out:
# 0.745398773006135

# %%
"""
KNN
"""

from sklearn.neighbors import KNeighborsClassifier

X = np.array(features)
y = np.array(target)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

#scaler = StandardScaler()
#X_train = scaler.fit_transform(X_train)
#X_test = scaler.fit_transform(X_test)

knn = KNeighborsClassifier()

k_range = list(range(1, 31))
#param_grid = dict(n_neighbors=k_range)
make_pipe = make_pipeline(StandardScaler(), KNeighborsClassifier())
  
# defining parameter range
param_grid = {'n_neighbors': k_range, 
              'p': [1, 2],
              'weights': ['uniform', 'distance']} 
  
grid = GridSearchCV(make_pipe, param_grid)
  
# fitting the model for grid search
grid_search=grid.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [113], in <cell line: 30>()
#      27 grid = GridSearchCV(make_pipe, param_grid)
#      29 # fitting the model for grid search
# ---> 30 grid_search=grid.fit(X_train, y_train)
#
# File /opt/pub/eb/apps/all/DavidsonJupyter/2021-common-GCCcore-10.2.0/lib/python3.8/site-packages/sklearn/model_selection/_search.py:875, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     869     results = self._format_results(
#     870         all_candidate_params, n_splits, all_out, all_more_results
#     871     )
#     873     return results
# --> 875 self._run_search(evaluate_candidates)
#     877 # multimetric is determined here because in the case of a callable
#     878 # self.scoring the return type is only known after calling
#     879 first_test_score = all_out[0]["test_scores"]
#
# File /opt/pub/eb/apps/all/DavidsonJupyter/2021-common-GCCcore-10.2.0/lib/python3.8/site-packages/sklearn/model_selection/_search.py:1375, in GridSearchCV._run_search(self, evaluate_candidates)
#    1373 def _run_search(self, evaluate_candidates):
#    1374     """Search all candidates in param_grid"""
# -> 1375     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File /opt/pub/eb/apps/all/DavidsonJupyter/2021-common-GCCcore-10.2.0/lib/python3.8/site-packages/sklearn/model_selection/_search.py:822, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     814 if self.verbose > 0:
#     815     print(
#     816         "Fitting {0} folds for each of {1} candidates,"
#     817         " totalling {2} fits".format(
#     818             n_splits, n_candidates, n_candidates * n_splits
#     819         )
#     820     )
# --> 822 out = parallel(
#     823     delayed(_fit_and_score)(
#     824         clone(base_estimator),
#     825         X,
#     826         y,
#     827         train=train,
#     828         test=test,
#     829         parameters=parameters,
#     830         split_progress=(split_idx, n_splits),
#     831         candidate_progress=(cand_idx, n_candidates),
#     832         **fit_and_score_kwargs,
#     833     )
#     834     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     835         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     836     )
#     837 )
#     839 if len(out) < 1:
#     840     raise ValueError(
#     841         "No fits were performed. "
#     842         "Was the CV iterator empty? "
#     843         "Were there no candidates?"
#     844     )
#
# File /opt/pub/eb/apps/all/DavidsonJupyter/2021-common-GCCcore-10.2.0/lib/python3.8/site-packages/joblib/parallel.py:1043, in Parallel.__call__(self, iterable)
#    1034 try:
#    1035     # Only set self._iterating to True if at least a batch
#    1036     # was dispatched. In particular this covers the edge
#    (...)
#    1040     # was very quick and its callback already dispatched all the
#    1041     # remaining jobs.
#    1042     self._iterating = False
# -> 1043     if self.dispatch_one_batch(iterator):
#    1044         self._iterating = self._original_iterator is not None
#    1046     while self.dispatch_one_batch(iterator):
#
# File /opt/pub/eb/apps/all/DavidsonJupyter/2021-common-GCCcore-10.2.0/lib/python3.8/site-packages/joblib/parallel.py:861, in Parallel.dispatch_one_batch(self, iterator)
#     859     return False
#     860 else:
# --> 861     self._dispatch(tasks)
#     862     return True
#
# File /opt/pub/eb/apps/all/DavidsonJupyter/2021-common-GCCcore-10.2.0/lib/python3.8/site-packages/joblib/parallel.py:779, in Parallel._dispatch(self, batch)
#     777 with self._lock:
#     778     job_idx = len(self._jobs)
# --> 779     job = self._backend.apply_async(batch, callback=cb)
#     780     # A job can complete so quickly than its callback is
#     781     # called before we get here, causing self._jobs to
#     782     # grow. To ensure correct results ordering, .insert is
#     783     # used (rather than .append) in the following line
#     784     self._jobs.insert(job_idx, job)
#
# File /opt/pub/eb/apps/all/DavidsonJupyter/2021-common-GCCcore-10.2.0/lib/python3.8/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File /opt/pub/eb/apps/all/DavidsonJupyter/2021-common-GCCcore-10.2.0/lib/python3.8/site-packages/joblib/_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File /opt/pub/eb/apps/all/DavidsonJupyter/2021-common-GCCcore-10.2.0/lib/python3.8/site-packages/joblib/parallel.py:262, in BatchedCalls.__call__(self)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File /opt/pub/eb/apps/all/DavidsonJupyter/2021-common-GCCcore-10.2.0/lib/python3.8/site-packages/joblib/parallel.py:262, in <listcomp>(.0)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File /opt/pub/eb/apps/all/DavidsonJupyter/2021-common-GCCcore-10.2.0/lib/python3.8/site-packages/sklearn/utils/fixes.py:117, in _FuncWrapper.__call__(self, *args, **kwargs)
#     115 def __call__(self, *args, **kwargs):
#     116     with config_context(**self.config):
# --> 117         return self.function(*args, **kwargs)
#
# File /opt/pub/eb/apps/all/DavidsonJupyter/2021-common-GCCcore-10.2.0/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:674, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     671     for k, v in parameters.items():
#     672         cloned_parameters[k] = clone(v, safe=False)
# --> 674     estimator = estimator.set_params(**cloned_parameters)
#     676 start_time = time.time()
#     678 X_train, y_train = _safe_split(estimator, X, y, train)
#
# File /opt/pub/eb/apps/all/DavidsonJupyter/2021-common-GCCcore-10.2.0/lib/python3.8/site-packages/sklearn/pipeline.py:188, in Pipeline.set_params(self, **kwargs)
#     169 def set_params(self, **kwargs):
#     170     """Set the parameters of this estimator.
#     171
#     172     Valid parameter keys can be listed with ``get_params()``. Note that
#    (...)
#     186         Pipeline class instance.
#     187     """
# --> 188     self._set_params("steps", **kwargs)
#     189     return self
#
# File /opt/pub/eb/apps/all/DavidsonJupyter/2021-common-GCCcore-10.2.0/lib/python3.8/site-packages/sklearn/utils/metaestimators.py:72, in _BaseComposition._set_params(self, attr, **params)
#      69                 self._replace_estimator(attr, name, params.pop(name))
#      71 # 3. Step parameters and other initialisation arguments
# ---> 72 super().set_params(**params)
#      73 return self
#
# File /opt/pub/eb/apps/all/DavidsonJupyter/2021-common-GCCcore-10.2.0/lib/python3.8/site-packages/sklearn/base.py:246, in BaseEstimator.set_params(self, **params)
#     244 if key not in valid_params:
#     245     local_valid_params = self._get_param_names()
# --> 246     raise ValueError(
#     247         f"Invalid parameter {key!r} for estimator {self}. "
#     248         f"Valid parameters are: {local_valid_params!r}."
#     249     )
#     251 if delim:
#     252     nested_params[key][sub_key] = value
#
# ValueError: Invalid parameter 'n_neighbors' for estimator Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('kneighborsclassifier', KNeighborsClassifier())]). Valid parameters are: ['memory', 'steps', 'verbose'].

# %%
"""
Random Forest
"""

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

X = np.array(features)
y = np.array(target)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

#parameter notes:
# how many trees do you need = n_estimators
# can't go wrong with super high because individual trees will overfit, and then the average will smooth that out
tree_range = [10, 100, 1000, 10000, 100000]

for i in range(len(tree_range)):
    randfor = RandomForestClassifier(n_estimators = tree_range[i])
    randfor.fit(X_train, y_train)
    scores = cross_val_score(randfor, X_train, y_train, cv=5)
    print(tree_range[i], np.mean(scores))
# Out:
# 10 0.7546101517530089
# 100 0.7627734170591314
# 1000 0.7719832548403976
# 10000 0.7689220303506017
# 100000 0.7699424385138671
